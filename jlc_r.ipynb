# %%
from numpy import *

# %%
r_values = [
    0,
    1,
    2,
    2.2,
    4.7,
    5.1,
    10,
    20,
    22,
    33,
    47,
    49.9,
    51,
    75,
    100,
    120,
    150,
    200,
    220,
    270,
    300,
    330,
    390,
    470,
    510,
    560,
    680,
    820,
    1000,
    1200,
    1500,
    1800,
    2000,
    2200,
    2400,
    2700,
    3000,
    3300,
    3600,
    3900,
    4700,
    4990,
    5100,
    5600,
    6200,
    6800,
    7500,
    8200,
    9100,
    10000,
    12000,
    13000,
    15000,
    18000,
    20000,
    22000,
    24000,
    27000,
    30000,
    33000,
    39000,
    47000,
    49900,
    51000,
    56000,
    68000,
    75000,
    82000,
    100000,
    120000,
    150000,
    200000,
    220000,
    300000,
    330000,
    470000,
    510000,
    1000000,
    2000000,
    10000000
]

# %%
r_target = 680000

# %%
i_a = range(len(r_values))
i_b = range(len(r_values))
ii_a, ii_b = meshgrid(i_a, i_b, sparse=True)

# %%
all_vals = r_values[ii_a] + r_values[ii_b]
abs_err = abs(all_vals - r_target)
i_best = unravel_index(abs_err.argmin(), abs_err.shape)
r_sel = all_vals[i_best]
r_a = r_values[i_best[0]]
r_b = r_values[i_best[1]]
error = (r_sel - r_target) / r_target

print("best match:", r_sel, r_a, r_b)
print('error:', error)
# Out:
# best match: 670000.0 200000.0 470000.0
# error: -0.014705882352941176

# %%
from itertools import combinations_with_replacement

# %%
def r_s(rr):
    return sum(rr)

def r_p(rr):
    if min(rr) == 0.0:
        return 0.0
    return 1.0 / sum(1.0 / r for r in rr)

def r_2p_s(rr):
    return r_p(rr[:2]) + r_s(rr[2:])

def r_2s_p(rr):
    return r_s(rr[:2]) + r_p(rr[2:])

def best_combo(values, target, max_n=3):
    best = None
    best_err = float("inf")

    for n in range(1, max_n + 1):
        modes = [r_s, r_p]
        if n >= 3:
            modes += [r_2p_s, r_2s_p]

        for combo in combinations_with_replacement(values, n):
            for mode in modes:
                r = mode(combo)
                err = abs(r - target)
                if err < best_err:
                    best_err = err
                    best = (combo, mode, r)
                    if err == 0.0:
                        return best, best_err

    return best, best_err

# %%
best_combo(r_values, r_target, 2)
# Out:
# (((200000, 470000), <function __main__.r_s(rr)>, 670000), 10000)
